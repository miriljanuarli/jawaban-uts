# %%
import pandas as pd

# Memanggil dataset
df = pd.read_csv('/content/testcpns.csv')

# Menampilkan ringkasan data seperti tabel pada soal
ringkasan = df.describe()

print(ringkasan)
# Out:
#             toefl        ipk  pengalaman_kerja   diterima
# count   40.000000  40.000000         40.000000  40.000000
# mean   654.000000   2.694500          3.425000   0.475000
# std     61.427464   0.653899          1.737778   0.505736
# min    540.000000   1.070000          1.000000   0.000000
# 25%    607.500000   2.070000          2.000000   0.000000
# 50%    660.000000   3.030000          4.000000   0.000000
# 75%    690.000000   3.070000          5.000000   1.000000
# max    780.000000   4.000000          6.000000   1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Memanggil dataset
df = pd.read_csv('/content/testcpns.csv')

# Membuat figure dengan 3 scatter plot
plt.figure(figsize=(15,5))

# Scatter Plot 1
plt.subplot(1,3,1)
sns.scatterplot(
    data=df,
    x='toefl',
    y='ipk',
    hue='diterima'
)
plt.title('TOEFL vs IPK')

# Scatter Plot 2
plt.subplot(1,3,2)
sns.scatterplot(
    data=df,
    x='toefl',
    y='pengalaman_kerja',
    hue='diterima'
)
plt.title('TOEFL vs Pengalaman Kerja')

# Scatter Plot 3
plt.subplot(1,3,3)
sns.scatterplot(
    data=df,
    x='ipk',
    y='pengalaman_kerja',
    hue='diterima'
)
plt.title('IPK vs Pengalaman Kerja')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Memanggil dataset
df = pd.read_csv('/content/testcpns.csv')

# Membuat 3 visualisasi seperti contoh soal
fig, axes = plt.subplots(1, 3, figsize=(15,5), sharey=True)

# Grafik 1
sns.scatterplot(
    data=df,
    x='ipk',
    y='diterima',
    ax=axes[0]
)
axes[0].set_title('ipk')

# Grafik 2
sns.scatterplot(
    data=df,
    x='pengalaman_kerja',
    y='diterima',
    ax=axes[1]
)
axes[1].set_title('pengalaman kerja')

# Grafik 3
sns.scatterplot(
    data=df,
    x='toefl',
    y='diterima',
    ax=axes[2]
)
axes[2].set_title('toefl')

plt.tight_layout()
plt.show()

# %%
# Import library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# Membaca dataset
df = pd.read_csv('testcpns.csv')

# Menentukan fitur dan target
X = df[['toefl', 'ipk', 'pengalaman_kerja']]
y = df['diterima']

# Membagi data training dan testing
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=42
)

# Membuat model Logistic Regression
model = LogisticRegression()

# Training model
model.fit(X_train, y_train)

# Prediksi
y_pred = model.predict(X_test)

# Membuat confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Menampilkan grafik confusion matrix
plt.figure(figsize=(6,5))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues'
)

plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.show()

# %%
import pandas as pd
import numpy as np

# 1. Membuat data indeks dan fitur sesuai dengan gambar soal P5.e
data_p5e = {
    'toefl': [550, 620, 670, 680, 610, 610, 650, 690, 540, 660, 580, 650],
    'ipk': [2.3, 3.3, 3.3, 3.9, 2.7, 3.0, 3.7, 3.7, 2.7, 3.3, 2.3, 2.3],
    'pengalaman_kerja': [4, 2, 6, 4, 3, 1, 6, 5, 2, 5, 2, 1]
}
indices = [22, 20, 25, 4, 10, 15, 28, 11, 18, 29, 27, 35]
df_test = pd.DataFrame(data_p5e, index=indices)

# Array hasil prediksi dari model (y_pred)
y_pred = [0, 0, 1, 1, 0, 0, 1, 1, 0, 1, 0, 0]

# 2. Menambahkan kolom 'diterima' berdasarkan hasil prediksi
df_test['diterima'] = y_pred

# Menampilkan hasil dengan format IPK dua desimal agar serupa dengan gambar target
df_test_formatted = df_test.copy()
df_test_formatted['ipk'] = df_test_formatted['ipk'].map('{:05.2f}'.format)
print("Hasil Tabel Penggabungan Prediksi:")
display(df_test_formatted)
# Out:
# Hasil Tabel Penggabungan Prediksi:
#     toefl    ipk  pengalaman_kerja  diterima
# 22    550  02.30                 4         0
# 20    620  03.30                 2         0
# 25    670  03.30                 6         1
# 4     680  03.90                 4         1
# 10    610  02.70                 3         0
# 15    610  03.00                 1         0
# 28    650  03.70                 6         1
# 11    690  03.70                 5         1
# 18    540  02.70                 2         0
# 29    660  03.30                 5         1
# 27    580  02.30                 2         0
# 35    650  02.30                 1         0

# %%
from sklearn.linear_model import LogisticRegression

# 1. Menyiapkan Data Latih (X dan y dari poin e)
X_train = df_test[['toefl', 'ipk', 'pengalaman_kerja']]
y_train = df_test['diterima']

# 2. Inisialisasi dan Latih Model Klasifikasi
# Menggunakan Logistic Regression karena ini adalah masalah klasifikasi biner
model_logreg = LogisticRegression()
model_logreg.fit(X_train, y_train)

# 3. Membuat Data Pelamar Baru sesuai tabel soal P5.f
data_baru = {
    'toefl': [590, 740, 680, 610, 710],
    'ipk': [2.0, 3.07, 3.03, 2.03, 3.0],
    'pengalaman_kerja': [3, 4, 6, 1, 5]
}
df_baru = pd.DataFrame(data_baru)

# 4. Melakukan Prediksi
prediksi_baru = model_logreg.predict(df_baru)
df_baru['diterima_prediksi'] = prediksi_baru

print("\nHasil Prediksi Pelamar Baru:")
display(df_baru)
# Out:
# Hasil Prediksi Pelamar Baru:
#    toefl   ipk  pengalaman_kerja  diterima_prediksi
# 0    590  2.00                 3                  0
# 1    740  3.07                 4                  1
# 2    680  3.03                 6                  1
# 3    610  2.03                 1                  0
# 4    710  3.00                 5                  1
